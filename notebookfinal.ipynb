# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Daniel**

# %% [markdown]
# Data Science Consultant

# %% [markdown]
# *I am interested in data science as it serves as a great introduction into both critical thinking skills and coding. It is a flexible hard skill to learn and can serve you well in nearly any respected occupation.*

# %% [markdown]
# ### The next cell is going to calculate a simple equation: 4x4.

# %%
print(4 * 4)
# Out:
# 16

# %% [markdown]
# ~~Strikethrough~~, https/www.google.com,
# > Blockquote
